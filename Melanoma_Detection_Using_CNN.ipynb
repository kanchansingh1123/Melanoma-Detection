# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
# Let's import required library

import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import seaborn as sns
from tensorflow.keras.utils import plot_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from tensorflow.keras.preprocessing.image import load_img

import warnings
warnings.filterwarnings('ignore')

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %%
# Let's unzip the data

# !unzip "/content/gdrive/My Drive/Machine Learning/CNN/melonama/CNN_assignment.zip" -d '/content/gdrive/My Drive/Machine Learning/CNN/melonama/'

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
data_dir_train = pathlib.Path("/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/")
data_dir_test = pathlib.Path('/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Test/')

# %%
print(data_dir_train)
print(data_dir_test)
# Out:
# /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train
# /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Test

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
# Write your train dataset here
# Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
# Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split=0.2,
    image_size = (img_height,img_width),
    batch_size = batch_size,
    subset = "training"
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
# Write your validation dataset here
# Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
# Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split=0.2,
    image_size= (img_height, img_width),
    batch_size= batch_size,
    subset='validation'
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

# your code goes here, you can use training or validation data to visualize

fig = plt.figure(figsize=(10, 10))
for i in range(9):
  plt.subplot(3,3,i+1)
  image = plt.imread(str(list(data_dir_train.glob(class_names[i]+'/*.jpg'))[1]))
  plt.title(class_names[i])
  plt.imshow(image)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
# Model 1 - Basic CNN Model Architecture

num_class = 9

# A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
model = Sequential()

model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)))

# Let's add first Convolution layer
model.add(layers.Conv2D(filters = 16, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Let's add second Convolution layer
model.add(layers.Conv2D(filters = 32, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Let's add third Convolution layer
model.add(layers.Conv2D(filters = 64, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Let's add fourth Convolution layer
model.add(layers.Conv2D(filters = 128, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))

# Let's add Flatten layer. It converts into 1D feature vector and  Flattens all its structure to create a single long feature vector
# Flattens the input. Does not affect the batch size.

model.add(layers.Flatten())

# Let's add fully connected layer (Dense layer)
model.add(layers.Dense(128, activation="relu"))

# Let's add output layer
model.add(layers.Dense(num_class, activation='softmax'))

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
# Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 11, 11, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 15488)             0
#
#  dense (Dense)               (None, 128)               1982592
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 2,081,193
# Trainable params: 2,081,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Let's vizualizing the model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 698s 2s/step - loss: 2.0035 - accuracy: 0.2188 - val_loss: 1.8150 - val_accuracy: 0.4004
# Epoch 2/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.6844 - accuracy: 0.3934 - val_loss: 1.4575 - val_accuracy: 0.4989
# Epoch 3/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.4645 - accuracy: 0.4838 - val_loss: 1.5169 - val_accuracy: 0.4698
# Epoch 4/20
# 56/56 [==============================] - 1s 21ms/step - loss: 1.3735 - accuracy: 0.5285 - val_loss: 1.4223 - val_accuracy: 0.4832
# Epoch 5/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.3158 - accuracy: 0.5268 - val_loss: 1.3727 - val_accuracy: 0.5324
# Epoch 6/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.2809 - accuracy: 0.5525 - val_loss: 1.4009 - val_accuracy: 0.5056
# Epoch 7/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.1764 - accuracy: 0.5915 - val_loss: 1.2654 - val_accuracy: 0.5705
# Epoch 8/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1419 - accuracy: 0.5965 - val_loss: 1.3503 - val_accuracy: 0.5347
# Epoch 9/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.1461 - accuracy: 0.5943 - val_loss: 1.3470 - val_accuracy: 0.5526
# Epoch 10/20
# 56/56 [==============================] - 1s 22ms/step - loss: 1.0503 - accuracy: 0.6161 - val_loss: 1.3123 - val_accuracy: 0.5257
# Epoch 11/20
# 56/56 [==============================] - 1s 21ms/step - loss: 0.9364 - accuracy: 0.6747 - val_loss: 1.3391 - val_accuracy: 0.5638
# Epoch 12/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.8749 - accuracy: 0.6864 - val_loss: 1.4969 - val_accuracy: 0.4787
# Epoch 13/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.8203 - accuracy: 0.7070 - val_loss: 1.6543 - val_accuracy: 0.5235
# Epoch 14/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.7761 - accuracy: 0.7165 - val_loss: 1.8290 - val_accuracy: 0.5727
# Epoch 15/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.6822 - accuracy: 0.7545 - val_loss: 1.5841 - val_accuracy: 0.5839
# Epoch 16/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6645 - accuracy: 0.7584 - val_loss: 1.7470 - val_accuracy: 0.5414
# Epoch 17/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5679 - accuracy: 0.7919 - val_loss: 1.8528 - val_accuracy: 0.5436
# Epoch 18/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4901 - accuracy: 0.8170 - val_loss: 1.8838 - val_accuracy: 0.5414
# Epoch 19/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.5687 - accuracy: 0.8008 - val_loss: 1.8873 - val_accuracy: 0.5705
# Epoch 20/20
# 56/56 [==============================] - 1s 22ms/step - loss: 0.4141 - accuracy: 0.8410 - val_loss: 2.0676 - val_accuracy: 0.5682

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# **Findings**: Model is overfitting, with less than 84% as training accuracies and less than 56% as validation accuracies.

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

# Let's use horizontal_and_vertical flip method to augment
data_augmentation = Sequential([
  layers.experimental.preprocessing.RandomFlip(mode="horizontal_and_vertical", input_shape=(img_height, img_width, 3)),
  layers.experimental.preprocessing.RandomRotation(0.1),
  layers.experimental.preprocessing.RandomZoom(0.1),
  layers.experimental.preprocessing.RandomTranslation(1, .5, fill_mode="reflect", interpolation="bilinear", seed=None, fill_value=0.0),
  layers.experimental.preprocessing.RandomCrop(img_height, img_width),
])

# %%
# Let's plot one augmented image from training dataset

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(len(class_names)):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")
    plt.title(class_names[0])
    
# plt.show()

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
# You can use Dropout layer if there is an evidence of overfitting in your findings

# Model 2 : Let's add data_augmentation, rescaling and dropout on top of Model 1

num_class = 9

# A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
model = Sequential(data_augmentation)

model.add(layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)))

# Let's add first Convolution layer
model.add(layers.Conv2D(filters = 16, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add second Convolution layer
model.add(layers.Conv2D(filters = 32, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add third Convolution layer
model.add(layers.Conv2D(filters = 64, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add fourth Convolution layer
model.add(layers.Conv2D(filters = 128, kernel_size=(3,3), padding='same', activation='relu'))

# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))


# Let's add Flatten layer. It converts into 1D feature vector and  Flattens all its structure to create a single long feature vector
# Flattens the input. Does not affect the batch size.

model.add(layers.Flatten())

# Let's add fully connected layer (Dense layer)
model.add(layers.Dense(128, activation="relu"))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add output layer
model.add(layers.Dense(num_class, activation='softmax'))

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_8 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_8 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 90, 90, 16)        0
#
#  conv2d_9 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_9 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 45, 45, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_10 (MaxPoolin  (None, 22, 22, 64)       0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 22, 22, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 22, 22, 128)       73856
#
#  max_pooling2d_11 (MaxPoolin  (None, 11, 11, 128)      0
#  g2D)
#
#  dropout_8 (Dropout)         (None, 11, 11, 128)       0
#
#  flatten_2 (Flatten)         (None, 15488)             0
#
#  dense_4 (Dense)             (None, 128)               1982592
#
#  dropout_9 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 2,081,193
# Trainable params: 2,081,193
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Let's vizualise the model 
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 6s 41ms/step - loss: 2.1084 - accuracy: 0.1970 - val_loss: 2.0801 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 2s 35ms/step - loss: 2.0291 - accuracy: 0.1948 - val_loss: 2.0574 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 2s 34ms/step - loss: 2.0102 - accuracy: 0.2333 - val_loss: 1.9136 - val_accuracy: 0.3043
# Epoch 4/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.8854 - accuracy: 0.2757 - val_loss: 1.7833 - val_accuracy: 0.3468
# Epoch 5/20
# 56/56 [==============================] - 2s 39ms/step - loss: 1.7595 - accuracy: 0.3248 - val_loss: 1.7181 - val_accuracy: 0.3400
# Epoch 6/20
# 56/56 [==============================] - 2s 35ms/step - loss: 1.7212 - accuracy: 0.3516 - val_loss: 1.7649 - val_accuracy: 0.3087
# Epoch 7/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6871 - accuracy: 0.3538 - val_loss: 1.7343 - val_accuracy: 0.3132
# Epoch 8/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6830 - accuracy: 0.3655 - val_loss: 1.8815 - val_accuracy: 0.2908
# Epoch 9/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6780 - accuracy: 0.3549 - val_loss: 1.8539 - val_accuracy: 0.3065
# Epoch 10/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.6105 - accuracy: 0.3996 - val_loss: 1.7628 - val_accuracy: 0.3468
# Epoch 11/20
# 56/56 [==============================] - 2s 39ms/step - loss: 1.6034 - accuracy: 0.3940 - val_loss: 1.8126 - val_accuracy: 0.3423
# Epoch 12/20
# 56/56 [==============================] - 2s 36ms/step - loss: 1.6473 - accuracy: 0.3783 - val_loss: 1.8115 - val_accuracy: 0.3378
# Epoch 13/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.6464 - accuracy: 0.3884 - val_loss: 1.7602 - val_accuracy: 0.3758
# Epoch 14/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.5994 - accuracy: 0.4241 - val_loss: 1.7226 - val_accuracy: 0.4027
# Epoch 15/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.5417 - accuracy: 0.4375 - val_loss: 1.6765 - val_accuracy: 0.4161
# Epoch 16/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.5473 - accuracy: 0.4224 - val_loss: 1.8278 - val_accuracy: 0.3714
# Epoch 17/20
# 56/56 [==============================] - 2s 36ms/step - loss: 1.5484 - accuracy: 0.4297 - val_loss: 1.6576 - val_accuracy: 0.4004
# Epoch 18/20
# 56/56 [==============================] - 2s 34ms/step - loss: 1.5092 - accuracy: 0.4353 - val_loss: 2.1223 - val_accuracy: 0.3378
# Epoch 19/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.5095 - accuracy: 0.4587 - val_loss: 1.8336 - val_accuracy: 0.4004
# Epoch 20/20
# 56/56 [==============================] - 2s 33ms/step - loss: 1.4732 - accuracy: 0.4621 - val_loss: 2.0234 - val_accuracy: 0.4004

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# Model 2 observations:
#
#
# 1.   Train dataset accuracy has come down.
# 2.   Data augumentation helpled to fix model **Overritting** problem as train and test accuracies has less difference.
# 3.   Model is now **Underfitting** as accuracy is low.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
path_list = []
label_list = []

for i in class_names:   
    for j in data_dir_train.glob(i+'/*.jpg'):
        path_list.append(str(j))
        label_list.append(i)

dataframe_dict_original = dict(zip(path_list, label_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path              Label
# 0     /content/gdrive/My Drive/Machine Learning/CNN/...  actinic keratosis
# 1     /content/gdrive/My Drive/Machine Learning/CNN/...  actinic keratosis
# 2     /content/gdrive/My Drive/Machine Learning/CNN/...  actinic keratosis
# 3     /content/gdrive/My Drive/Machine Learning/CNN/...  actinic keratosis
# 4     /content/gdrive/My Drive/Machine Learning/CNN/...  actinic keratosis
# ...                                                 ...                ...
# 2234  /content/gdrive/My Drive/Machine Learning/CNN/...    vascular lesion
# 2235  /content/gdrive/My Drive/Machine Learning/CNN/...    vascular lesion
# 2236  /content/gdrive/My Drive/Machine Learning/CNN/...    vascular lesion
# 2237  /content/gdrive/My Drive/Machine Learning/CNN/...    vascular lesion
# 2238  /content/gdrive/My Drive/Machine Learning/CNN/...    vascular lesion
#
# [2239 rows x 2 columns]

# %%
# Let's visulasie the distribution of the class in training dataset 
def class_distribution(directory):
    count= []
    for path in pathlib.Path(directory).iterdir():
      if path.is_dir():
        count.append(len([name for name in os.listdir(path)
          if os.path.isfile(os.path.join(path, name))]))
    
    # Name of the classes
    sub_directory = [name for name in os.listdir(directory)
      if os.path.isdir(os.path.join(directory, name))]
    
    # Return dataframe with image count and class.
    return pd.DataFrame(list(zip(sub_directory,count)),columns =['Class', 'No. of Image'])

df = class_distribution(data_dir_train)
df
# Out:
#                         Class  No. of Image
# 0           actinic keratosis           114
# 1        basal cell carcinoma           376
# 2              dermatofibroma            95
# 3                    melanoma           438
# 4                       nevus           357
# 5  pigmented benign keratosis           462
# 6        seborrheic keratosis            77
# 7     squamous cell carcinoma           181
# 8             vascular lesion           139

# %%
# Let's plot the graph
plt.figure(figsize=(22,8))
plt.bar(df['Class'], df['No. of Image'])
plt.show()

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
#
#
# *   **Seborrheic keratosis**
#
#
# #### - Which classes dominate the data in terms proportionate number of samples?
#
#
# *   **pigmented benign keratosis**

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.22.4)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) # We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F13CAE27340>: 100%|██████████| 500/500 [00:20<00:00, 23.92 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F13CB4DD4B0>: 100%|██████████| 500/500 [00:22<00:00, 22.42 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1452E30340>: 100%|██████████| 500/500 [00:22<00:00, 22.39 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F13D6638FD0>: 100%|██████████| 500/500 [01:50<00:00,  4.52 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=1504x1129 at 0x7F13C6CE34F0>: 100%|██████████| 500/500 [01:39<00:00,  5.03 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F1452D8D960>: 100%|██████████| 500/500 [00:20<00:00, 24.77 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F13D64EEDD0>: 100%|██████████| 500/500 [00:49<00:00, 10.15 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F13CB6C6560>: 100%|██████████| 500/500 [00:19<00:00, 25.29 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F13CAD3DF90>: 100%|██████████| 500/500 [00:22<00:00, 22.50 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
# Let's priint the total images in output directory
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
# import glob
from glob import glob

path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list
# Out:
# ['/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026709.jpg_6220e8ba-ee61-4534-b092-6cb5af59d55e.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033358.jpg_53d1f245-d86e-4211-8176-d0fc1aa1efd9.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028941.jpg_a67ae787-0369-4929-881b-f326bf8b801a.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027562.jpg_c2a0f840-ba65-41d8-be82-1e906c21ea34.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027334.jpg_e8956ed2-785d-424b-9ff2-850a85ed0304.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032437.jpg_cbc46d31-7d96-4692-a482-245574b85dbb.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028820.jpg_a7eb0f2d-de01-4bdd-8622-7f5c1436715c.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027958.jpg_76fec4a6-cf66-42f5-b076-1a6ae02a4dfa.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031506.jpg_02292b2c-38bf-4379-a3f5-300be82a788b.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026765.jpg_022d30e1-916b-447c-b038-325118b586d4.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027452.jpg_d04fe6cc-840d-468f-9b6a-af27ca06ed21.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030242.jpg_9eeaff16-0227-4501-a629-94ef5275eafe.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030344.jpg_d274f729-9635-47f0-8b1b-d99d3bf2cf22.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031993.jpg_2b0134e5-5c7b-4beb-ab8c-5f901557a68d.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031292.jpg_221d31f8-94a2-47a9-8914-b99fb6755789.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032422.jpg_cf1d5afe-9b95-4059-a7c9-c7b2fa7896e3.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0033866.jpg_6baa1bd1-539b-4f07-aa16-93c57b011fdd.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025992.jpg_0e55443d-b0bb-4922-ac81-3d4ab584d525.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029827.jpg_4b2ff55e-15c4-415f-a2d6-f069e3e77f92.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0031228.jpg_fd5f1e86-c073-4d9e-92e0-7c1f2f47b3ff.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030826.jpg_3a8060c5-0b65-4ae5-965e-1c5d86fc9fbf.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028517.jpg_bb1dc16e-7696-4075-bf57-79e9887b34f7.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_012a8ed5-d7eb-4215-807f-cb5b36ac8b83.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0028820.jpg_9f0eb0b1-3024-489d-90f4-a51ee04ffc07.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027958.jpg_45f392d0-8dd7-473c-a3e8-cbd6ed3f72cf.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0032199.jpg_a212b37f-0cfd-4111-bd04-36915a64350b.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025780.jpg_f4896af3-882d-430e-a4b3-0eb6503393ac.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0025957.jpg_c485941e-9400-43c5-a9a5-099a35acea7c.jpg',
#  '/content/gdrive/My Drive/Machine Learning/CNN/melonama/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0030586.jpg
), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(layers.Conv2D(filters = 16, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
# Let's add pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add second Convolution layer
model.add(layers.Conv2D(filters = 32, kernel_size=(3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(layers.Conv2D(filters = 32, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add third Convolution layer
model.add(layers.Conv2D(filters = 64, kernel_size=(3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(layers.Conv2D(filters = 64, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add fourth Convolution layer
model.add(layers.Conv2D(filters = 128, kernel_size=(3,3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(layers.Conv2D(filters = 128, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
# Let's add another pooling layer to down samples
model.add(layers.MaxPooling2D(pool_size=(2,2)))
# Let us add some dropouts
model.add(layers.Dropout(0.25))


# Let's add Flatten layer. It converts into 1D feature vector and  Flattens all its structure to create a single long feature vector
# Flattens the input. Does not affect the batch size.

model.add(layers.Flatten())

# Let's add fully connected layer (Dense layer)
model.add(layers.Dense(128, activation="relu"))
# Let us add some dropouts
model.add(layers.Dropout(0.25))

# Let's add output layer
model.add(layers.Dense(num_class, activation='softmax'))

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_12 (Conv2D)          (None, 180, 180, 16)      448
#
#  batch_normalization (BatchN  (None, 180, 180, 16)     64
#  ormalization)
#
#  conv2d_13 (Conv2D)          (None, 178, 178, 16)      2320
#
#  batch_normalization_1 (Batc  (None, 178, 178, 16)     64
#  hNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 89, 89, 16)       0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 89, 89, 16)        0
#
#  conv2d_14 (Conv2D)          (None, 89, 89, 32)        4640
#
#  batch_normalization_2 (Batc  (None, 89, 89, 32)       128
#  hNormalization)
#
#  conv2d_15 (Conv2D)          (None, 87, 87, 32)        9248
#
#  batch_normalization_3 (Batc  (None, 87, 87, 32)       128
#  hNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 43, 43, 32)       0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 43, 43, 32)        0
#
#  conv2d_16 (Conv2D)          (None, 43, 43, 64)        18496
#
#  batch_normalization_4 (Batc  (None, 43, 43, 64)       256
#  hNormalization)
#
#  conv2d_17 (Conv2D)          (None, 41, 41, 64)        36928
#
#  batch_normalization_5 (Batc  (None, 41, 41, 64)       256
#  hNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 20, 20, 64)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 20, 20, 64)        0
#
#  conv2d_18 (Conv2D)          (None, 20, 20, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 20, 20, 128)      512
#  hNormalization)
#
#  conv2d_19 (Conv2D)          (None, 18, 18, 128)       147584
#
#  batch_normalization_7 (Batc  (None, 18, 18, 128)      512
#  hNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 9, 9, 128)        0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 9, 9, 128)         0
#
#  flatten_3 (Flatten)         (None, 10368)             0
#
#  dense_6 (Dense)             (None, 128)               1327232
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_7 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 1,623,833
# Trainable params: 1,622,873
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 56s 136ms/step - loss: 2.1986 - accuracy: 0.2795 - val_loss: 6.4934 - val_accuracy: 0.1128
# Epoch 2/30
# 169/169 [==============================] - 15s 88ms/step - loss: 1.7316 - accuracy: 0.3527 - val_loss: 2.1587 - val_accuracy: 0.2532
# Epoch 3/30
# 169/169 [==============================] - 15s 88ms/step - loss: 1.6147 - accuracy: 0.3859 - val_loss: 1.6830 - val_accuracy: 0.3653
# Epoch 4/30
# 169/169 [==============================] - 15s 87ms/step - loss: 1.4570 - accuracy: 0.4475 - val_loss: 1.2623 - val_accuracy: 0.5100
# Epoch 5/30
# 169/169 [==============================] - 15s 86ms/step - loss: 1.3414 - accuracy: 0.4844 - val_loss: 1.2091 - val_accuracy: 0.5360
# Epoch 6/30
# 169/169 [==============================] - 15s 90ms/step - loss: 1.2181 - accuracy: 0.5269 - val_loss: 2.3402 - val_accuracy: 0.3883
# Epoch 7/30
# 169/169 [==============================] - 15s 87ms/step - loss: 1.1376 - accuracy: 0.5612 - val_loss: 1.0682 - val_accuracy: 0.5947
# Epoch 8/30
# 169/169 [==============================] - 15s 87ms/step - loss: 1.0296 - accuracy: 0.5935 - val_loss: 1.1068 - val_accuracy: 0.6192
# Epoch 9/30
# 169/169 [==============================] - 15s 86ms/step - loss: 0.9596 - accuracy: 0.6317 - val_loss: 1.1866 - val_accuracy: 0.5984
# Epoch 10/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.8984 - accuracy: 0.6563 - val_loss: 1.1061 - val_accuracy: 0.6333
# Epoch 11/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.8014 - accuracy: 0.6873 - val_loss: 0.9114 - val_accuracy: 0.6696
# Epoch 12/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.7672 - accuracy: 0.7046 - val_loss: 0.8235 - val_accuracy: 0.6964
# Epoch 13/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.7183 - accuracy: 0.7268 - val_loss: 1.2207 - val_accuracy: 0.5984
# Epoch 14/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.6517 - accuracy: 0.7392 - val_loss: 2.9681 - val_accuracy: 0.4246
# Epoch 15/30
# 169/169 [==============================] - 15s 86ms/step - loss: 0.6383 - accuracy: 0.7481 - val_loss: 1.1449 - val_accuracy: 0.6503
# Epoch 16/30
# 169/169 [==============================] - 15s 86ms/step - loss: 0.6087 - accuracy: 0.7593 - val_loss: 2.0350 - val_accuracy: 0.5345
# Epoch 17/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.5848 - accuracy: 0.7702 - val_loss: 1.0878 - val_accuracy: 0.6637
# Epoch 18/30
# 169/169 [==============================] - 15s 86ms/step - loss: 0.5169 - accuracy: 0.7895 - val_loss: 0.7615 - val_accuracy: 0.7491
# Epoch 19/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.4976 - accuracy: 0.8021 - val_loss: 0.6819 - val_accuracy: 0.7468
# Epoch 20/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.4628 - accuracy: 0.8177 - val_loss: 0.9299 - val_accuracy: 0.7194
# Epoch 21/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.4645 - accuracy: 0.8218 - val_loss: 1.6650 - val_accuracy: 0.6414
# Epoch 22/30
# 169/169 [==============================] - 15s 86ms/step - loss: 0.4156 - accuracy: 0.8333 - val_loss: 0.6817 - val_accuracy: 0.7647
# Epoch 23/30
# 169/169 [==============================] - 15s 86ms/step - loss: 0.4068 - accuracy: 0.8448 - val_loss: 0.5521 - val_accuracy: 0.8085
# Epoch 24/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.3707 - accuracy: 0.8522 - val_loss: 0.5158 - val_accuracy: 0.8248
# Epoch 25/30
# 169/169 [==============================] - 15s 88ms/step - loss: 0.3579 - accuracy: 0.8585 - val_loss: 0.7358 - val_accuracy: 0.7647
# Epoch 26/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.3499 - accuracy: 0.8633 - val_loss: 0.8265 - val_accuracy: 0.7558
# Epoch 27/30
# 169/169 [==============================] - 15s 90ms/step - loss: 0.3299 - accuracy: 0.8681 - val_loss: 0.6412 - val_accuracy: 0.8025
# Epoch 28/30
# 169/169 [==============================] - 15s 91ms/step - loss: 0.3272 - accuracy: 0.8678 - val_loss: 0.5528 - val_accuracy: 0.8330
# Epoch 29/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.3263 - accuracy: 0.8733 - val_loss: 0.5982 - val_accuracy: 0.8114
# Epoch 30/30
# 169/169 [==============================] - 15s 87ms/step - loss: 0.3262 - accuracy: 0.8693 - val_loss: 0.8514 - val_accuracy: 0.7684

# %%
# Let's vizualise the model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ## Model 3 Observations :
#
#
# *   Model 3 with Batch Normalization + 30 epoch (As predefined in notebook) with class rebalancing helped to increase the Train and Validation accuracy.
# *   Train and Validation accuracy has lesser difference.
# * No Sign of Overfitting and underfittin.

# %% [markdown]
# ## **Model Prediction**
#
# Let's try to predict the image of **melanoma** class using model

# %%
# print(class_names)
# print(class_names[3])
test_image_path = os.path.join(data_dir_test, class_names[3], '*')
test_image = glob(test_image_path)
test_image = load_img(test_image[1], target_size=(180,180,3))
plt.imshow(test_image)
plt.title(class_names[3])
plt.grid(False)
plt.axis("off")
plt.show()

# %%
img = np.expand_dims(test_image,axis=0)
pred = model.predict(img)
pred = np.argmax(pred)
pred_class = class_names[pred]
print("Actual Class "+ class_names[3] +'\n'+ "Predictive Class "+pred_class )
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Actual Class melanoma
# Predictive Class melanoma
